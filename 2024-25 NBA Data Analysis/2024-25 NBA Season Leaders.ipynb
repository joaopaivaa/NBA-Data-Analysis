# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('..\\NBA Datasets\\GameLogs2024-25.csv', sep=';')
df
# Out:
#      SEASON_YEAR  PLAYER_ID       PLAYER_NAME  NICKNAME     TEAM_ID  \
# 0        2024-25    1629216      Gabe Vincent      Gabe  1610612747
# 1        2024-25    1642261     Dalton Knecht    Dalton  1610612747
# 2        2024-25    1628384        OG Anunoby        OG  1610612752
# 3        2024-25    1629675          Naz Reid       Naz  1610612750
# 4        2024-25    1630540     Miles McBride     Miles  1610612752
# ...          ...        ...               ...       ...         ...
# 7847     2024-25    1627741       Buddy Hield     Buddy  1610612744
# 7848     2024-25    1628973     Jalen Brunson     Jalen  1610612752
# 7849     2024-25    1630552     Jalen Johnson     Jalen  1610612737
# 7850     2024-25    1630228  Jonathan Kuminga  Jonathan  1610612744
# 7851     2024-25    1630578    Alperen Sengun   Alperen  1610612745
#
#      TEAM_ABBREVIATION               TEAM_NAME   GAME_ID            GAME_DATE  \
# 0                  LAL      Los Angeles Lakers  22400062  2024-10-22T00:00:00
# 1                  LAL      Los Angeles Lakers  22400062  2024-10-22T00:00:00
# 2                  NYK         New York Knicks  22400061  2024-10-22T00:00:00
# 3                  MIN  Minnesota Timberwolves  22400062  2024-10-22T00:00:00
# 4                  NYK         New York Knicks  22400061  2024-10-22T00:00:00
# ...                ...                     ...       ...                  ...
# 7847               GSW   Golden State Warriors  22401204  2024-12-11T00:00:00
# 7848               NYK         New York Knicks  22401202  2024-12-11T00:00:00
# 7849               ATL           Atlanta Hawks  22401202  2024-12-11T00:00:00
# 7850               GSW   Golden State Warriors  22401204  2024-12-11T00:00:00
# 7851               HOU         Houston Rockets  22401204  2024-12-11T00:00:00
#
#           MATCHUP  ... EFG_PCT_RANK  TS_PCT_RANK  USG_PCT_RANK  \
# 0     LAL vs. MIN  ...         3649         4478          6855
# 1     LAL vs. MIN  ...         2450         2840          5970
# 2       NYK @ BOS  ...         6621         6493          6358
# 3       MIN @ LAL  ...         3649         3014          4084
# 4       NYK @ BOS  ...          199          494          2277
# ...           ...  ...          ...          ...           ...
# 7847    GSW @ HOU  ...         2450         2840          4578
# 7848  NYK vs. ATL  ...         5183         5409          2469
# 7849    ATL @ NYK  ...         5013         5073          2115
# 7850    GSW @ HOU  ...         4723         5294           965
# 7851  HOU vs. GSW  ...         3289         2995           264
#
#       E_USG_PCT_RANK  E_PACE_RANK  PACE_RANK  sp_work_PACE_RANK  PIE_RANK  \
# 0               6717         4747       4982               4982      6145
# 1               5899         3728       4359               4359      4699
# 2               6358         6893       6618               6618      6307
# 3               4296         4389       5626               5626      4529
# 4               2136         7540       7535               7535      2066
# ...              ...          ...        ...                ...       ...
# 7847            4606         6221       7415               7415      3082
# 7848            2567         4213       4845               4845      3899
# 7849            1968         4528       4712               4712      1469
# 7850             859         6148       7509               7509      5143
# 7851             329         4025       5765               5765       250
#
#       FGM_PG_RANK  FGA_PG_RANK
# 0            5575         6354
# 1            4528         5340
# 2            5575         3748
# 3            3577         3284
# 4             749         2455
# ...           ...          ...
# 7847         1523         1740
# 7848         2104         1015
# 7849          749          315
# 7850          749          315
# 7851          316          524
#
# [7852 rows x 125 columns]

# %%
df.columns
# Out:
# Index(['SEASON_YEAR', 'PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP',
#        ...
#        'EFG_PCT_RANK', 'TS_PCT_RANK', 'USG_PCT_RANK', 'E_USG_PCT_RANK',
#        'E_PACE_RANK', 'PACE_RANK', 'sp_work_PACE_RANK', 'PIE_RANK',
#        'FGM_PG_RANK', 'FGA_PG_RANK'],
#       dtype='object', length=125)

# %%
df.isna().sum()
# Out:
# SEASON_YEAR          0
# PLAYER_ID            0
# PLAYER_NAME          0
# NICKNAME             0
# TEAM_ID              0
#                     ..
# PACE_RANK            0
# sp_work_PACE_RANK    0
# PIE_RANK             0
# FGM_PG_RANK          0
# FGA_PG_RANK          0
# Length: 125, dtype: int64

# %%
df = df.drop(columns=[col for col in df.columns if ('_' in col) and col != 'PLAYER_NAME'])
df
# Out:
#            PLAYER_NAME  NICKNAME      MATCHUP WL        MIN  FGM  FGA  FG3M  \
# 0         Gabe Vincent      Gabe  LAL vs. MIN  W  17.216667    1    2     0
# 1        Dalton Knecht    Dalton  LAL vs. MIN  W  15.783333    2    4     1
# 2           OG Anunoby        OG    NYK @ BOS  L  34.166667    1    7     0
# 3             Naz Reid       Naz    MIN @ LAL  L  26.350000    3    8     2
# 4        Miles McBride     Miles    NYK @ BOS  L  25.850000    8   10     4
# ...                ...       ...          ... ..        ...  ...  ...   ...
# 7847       Buddy Hield     Buddy    GSW @ HOU  L  35.041667    6   12     3
# 7848     Jalen Brunson     Jalen  NYK vs. ATL  L  35.516667    5   15     2
# 7849     Jalen Johnson     Jalen    ATL @ NYK  W  41.183333    8   20     1
# 7850  Jonathan Kuminga  Jonathan    GSW @ HOU  L  36.166667    8   20     2
# 7851    Alperen Sengun   Alperen  HOU vs. GSW  W  31.625000   10   18     0
#
#       FG3A  FTM  ...  BLK  BLKA  PF  PFD  PTS  DD2  TD3    PACE    PIE  POSS
# 0        0    0  ...    0     0   1    0    2    0    0   98.97  0.027    37
# 1        3    0  ...    0     0   1    0    5    0    0  100.36  0.070    34
# 2        4    2  ...    0     0   3    1    4    0    0   94.83  0.021    69
# 3        4    4  ...    0     0   3    2   12    0    0   97.46  0.074    53
# 4        5    2  ...    0     0   1    3   22    0    0   90.06  0.137    49
# ...    ...  ...  ...  ...   ...  ..  ...  ...  ...  ...     ...    ...   ...
# 7847     9    0  ...    3     0   3    0   15    0    0   91.09  0.109    68
# 7848     6    2  ...    1     2   0    2   14    0    0   99.33  0.090    73
# 7849     5    4  ...    2     3   1    4   21    1    0   99.65  0.157    87
# 7850     6    2  ...    1     2   2    4   20    0    0   90.25  0.059    68
# 7851     1    6  ...    0     2   0    6   26    1    0   97.14  0.256    62
#
# [7852 rows x 27 columns]

# %%
df_totals = df.groupby(by='PLAYER_NAME').sum(numeric_only=True).reset_index()
df_totals['MIN'] = df_totals['MIN'].round(2)
df_totals
# Out:
#          PLAYER_NAME     MIN  FGM  FGA  FG3M  FG3A  FTM  FTA  OREB  DREB  ...  \
# 0           AJ Green  487.60   62  130    56   118    5    6     4    46  ...
# 1         AJ Johnson   10.70    3    6     1     1    0    0     0     2  ...
# 2       Aaron Gordon  326.30   54  102    16    34   33   42    21    45  ...
# 3      Aaron Holiday  145.16   21   45    15    34    7    9     0    15  ...
# 4      Aaron Nesmith  136.22   19   36     6    11   11   13     4    20  ...
# ..               ...     ...  ...  ...   ...   ...  ...  ...   ...   ...  ...
# 497        Zach Edey  281.27   64  105     6    10   22   33    43    54  ...
# 498      Zach LaVine  733.26  177  350    73   169   60   75     5    92  ...
# 499       Zeke Nnaji   73.69    9   22     0     8    1    5     2     5  ...
# 500  Ziaire Williams  458.62   64  159    18    66   35   44    22    70  ...
# 501  Zion Williamson  186.36   47  104     2     6   40   60    16    32  ...
#
#      BLK  BLKA  PF  PFD  PTS  DD2  TD3     PACE    PIE  POSS
# 0      2     0  45   12  185    0    0  2290.99  1.617  1003
# 1      0     1   0    0    7    0    0   599.12  7.903    28
# 2      3     7  17   35  157    2    0  1158.04  1.149   701
# 3      1     0   7    9   64    0    0  1642.51  2.082   321
# 4      2     3  24   12   55    0    0   596.96  0.443   280
# ..   ...   ...  ..  ...  ...  ...  ...      ...    ...   ...
# 497   14     9  44   31  156    2    0  1459.93  1.607   608
# 498    6    12  40   61  487    1    0  2302.74  2.448  1596
# 499    2     3   6    8   19    0    0  1568.23  1.194   162
# 500    7    18  56   42  181    1    0  2042.90  1.201   925
# 501    7    19  18   40  136    3    0   595.02  0.649   385
#
# [502 rows x 24 columns]

# %%
df_mean = df.groupby(by='PLAYER_NAME').mean(numeric_only=True).reset_index()
df_mean = df_mean.round(2)
df_mean
# Out:
#          PLAYER_NAME    MIN   FGM    FGA  FG3M  FG3A   FTM    FTA  OREB  DREB  \
# 0           AJ Green  21.20  2.70   5.65  2.43  5.13  0.22   0.26  0.17  2.00
# 1         AJ Johnson   2.14  0.60   1.20  0.20  0.20  0.00   0.00  0.00  0.40
# 2       Aaron Gordon  29.66  4.91   9.27  1.45  3.09  3.00   3.82  1.91  4.09
# 3      Aaron Holiday   9.68  1.40   3.00  1.00  2.27  0.47   0.60  0.00  1.00
# 4      Aaron Nesmith  22.70  3.17   6.00  1.00  1.83  1.83   2.17  0.67  3.33
# ..               ...    ...   ...    ...   ...   ...   ...    ...   ...   ...
# 497        Zach Edey  20.09  4.57   7.50  0.43  0.71  1.57   2.36  3.07  3.86
# 498      Zach LaVine  33.33  8.05  15.91  3.32  7.68  2.73   3.41  0.23  4.18
# 499       Zeke Nnaji   4.91  0.60   1.47  0.00  0.53  0.07   0.33  0.13  0.33
# 500  Ziaire Williams  21.84  3.05   7.57  0.86  3.14  1.67   2.10  1.05  3.33
# 501  Zion Williamson  31.06  7.83  17.33  0.33  1.00  6.67  10.00  2.67  5.33
#
#      ...   BLK  BLKA    PF   PFD    PTS   DD2  TD3    PACE   PIE   POSS
# 0    ...  0.09  0.00  1.96  0.52   8.04  0.00  0.0   99.61  0.07  43.61
# 1    ...  0.00  0.20  0.00  0.00   1.40  0.00  0.0  119.82  1.58   5.60
# 2    ...  0.27  0.64  1.55  3.18  14.27  0.18  0.0  105.28  0.10  63.73
# 3    ...  0.07  0.00  0.47  0.60   4.27  0.00  0.0  109.50  0.14  21.40
# 4    ...  0.33  0.50  4.00  2.00   9.17  0.00  0.0   99.49  0.07  46.67
# ..   ...   ...   ...   ...   ...    ...   ...  ...     ...   ...    ...
# 497  ...  1.00  0.64  3.14  2.21  11.14  0.14  0.0  104.28  0.11  43.43
# 498  ...  0.27  0.55  1.82  2.77  22.14  0.05  0.0  104.67  0.11  72.55
# 499  ...  0.13  0.20  0.40  0.53   1.27  0.00  0.0  104.55  0.08  10.80
# 500  ...  0.33  0.86  2.67  2.00   8.62  0.05  0.0   97.28  0.06  44.05
# 501  ...  1.17  3.17  3.00  6.67  22.67  0.50  0.0   99.17  0.11  64.17
#
# [502 rows x 24 columns]

# %%
df_mean.to_csv('..\\NBA Datasets\\2024-25 Players Mean.csv', sep=';', index=False)
df_totals.to_csv('..\\NBA Datasets\\2024-25 Players Totals.csv', sep=';', index=False)

# %%
for stat in ['PTS','REB','AST','STL','BLK','TOV','FGM','FG3M','MIN']:
    df_filtered = df_totals.sort_values(stat, ascending=False).head(10).reset_index(drop=True).loc[:,['PLAYER_NAME', stat]]
    print(df_filtered)
    df_filtered = df_filtered.sort_values(stat, ascending=True)
    plt.barh(df_filtered['PLAYER_NAME'], df_filtered[stat], label=df_filtered[stat].values, color='#17408B')
    for i, value in enumerate(df_filtered[stat]):
        plt.text(value + 1, i, str(value), va='center', ha='left')
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['left'].set_visible(False)
    plt.gca().axes.get_xaxis().set_visible(False)
    plt.title(stat)
    plt.show()
    print('')
# Out:
#                PLAYER_NAME  PTS
# 0  Shai Gilgeous-Alexander  725
# 1    Giannis Antetokounmpo  720
# 2             De'Aaron Fox  660
# 3             Jayson Tatum  648
# 4            Anthony Davis  632
# 5            Jalen Brunson  618
# 6             Nikola Jokić  613
# 7             Franz Wagner  610
# 8          Anthony Edwards  607
# 9             Devin Booker  573
#              PLAYER_NAME  REB
# 0     Karl-Anthony Towns  312
# 1            Ivica Zubac  304
# 2       Domantas Sabonis  293
# 3           Jakob Poeltl  278
# 4         Alperen Sengun  265
# 5          Jarrett Allen  259
# 6          Anthony Davis  258
# 7           Nikola Jokić  258
# 8            Rudy Gobert  253
# 9  Giannis Antetokounmpo  250
#          PLAYER_NAME  AST
# 0         Trae Young  304
# 1  Tyrese Haliburton  210
# 2       LeBron James  210
# 3       James Harden  205
# 4         Chris Paul  205
# 5    Cade Cunningham  197
# 6      Jalen Brunson  195
# 7       Nikola Jokić  193
# 8        Josh Giddey  172
# 9     Damian Lillard  159
#                 PLAYER_NAME  STL
# 0             Dyson Daniels   73
# 1            Jalen Williams   49
# 2                Tari Eason   46
# 3  Kentavious Caldwell-Pope   43
# 4             Cason Wallace   43
# 5              Franz Wagner   43
# 6              De'Aaron Fox   43
# 7   Shai Gilgeous-Alexander   42
# 8                 Kris Dunn   41
# 9               Jalen Suggs   41
#          PLAYER_NAME  BLK
# 0  Victor Wembanyama   64
# 1     Walker Kessler   51
# 2        Brook Lopez   51
# 3       Myles Turner   47
# 4      Anthony Davis   46
# 5  Jaren Jackson Jr.   44
# 6    Donovan Clingan   37
# 7     Alexandre Sarr   37
# 8        Evan Mobley   37
# 9        Rudy Gobert   34
#              PLAYER_NAME  TOV
# 0             Trae Young  114
# 1           James Harden  105
# 2        Cade Cunningham   98
# 3           LeBron James   94
# 4           De'Aaron Fox   86
# 5            LaMelo Ball   81
# 6          Jalen Johnson   80
# 7  Giannis Antetokounmpo   76
# 8             Jaden Ivey   75
# 9       Domantas Sabonis   75
#                PLAYER_NAME  FGM
# 0    Giannis Antetokounmpo  284
# 1  Shai Gilgeous-Alexander  255
# 2             De'Aaron Fox  245
# 3             Nikola Jokić  233
# 4            Anthony Davis  227
# 5             Franz Wagner  220
# 6            Jalen Brunson  211
# 7          Anthony Edwards  211
# 8             Jayson Tatum  210
# 9           Nikola Vučević  209
#         PLAYER_NAME  FG3M
# 0   Anthony Edwards   103
# 1       Tyler Herro    92
# 2     Malik Beasley    92
# 3  Donovan Mitchell    90
# 4  Payton Pritchard    89
# 5      Jayson Tatum    88
# 6       LaMelo Ball    84
# 7     Derrick White    82
# 8    Brandon Miller    80
# 9       Buddy Hield    78
#          PLAYER_NAME     MIN
# 0      Mikal Bridges  958.08
# 1       De'Aaron Fox  930.46
# 2          Josh Hart  923.75
# 3         OG Anunoby  920.29
# 4      Keegan Murray  910.35
# 5         Trae Young  899.49
# 6  Tyrese Haliburton  883.88
# 7      Jalen Johnson  876.98
# 8      Pascal Siakam  860.55
# 9      Jalen Brunson  857.20
